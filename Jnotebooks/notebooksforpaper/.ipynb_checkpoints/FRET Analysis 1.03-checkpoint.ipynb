# %% [markdown]
# # Loading software

# %%
from fretbursts import *
sns = init_notebook()
import lmfit
import phconvert
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
# Out:
#  - Optimized (cython) burst search loaded.
#  - Optimized (cython) photon counting loaded.
# --------------------------------------------------------------
#  You are running FRETBursts (version 0.6.5).
#
#  If you use this software please cite the following paper:
#
#    FRETBursts: An Open Source Toolkit for Analysis of Freely-Diffusing Single-Molecule FRET
#    Ingargiola et al. (2016). http://dx.doi.org/10.1371/journal.pone.0160716
#
# --------------------------------------------------------------

# %% [markdown]
# # Name and Load in data
#
# first name the data file and check it exists, it will look for the file starting from inside the "Anaconda Projects Folder"

# %%
filename = "definitiveset/1x.hdf5"
if os.path.isfile(filename):
    print("File found")
else:
    print("File not found, check file name is correct")
# Out:
# File found

# %% [markdown]
# Load in the file and set correction factors. If you aren't using accurate correction factors, set d.leakage and d.dir_ex to 0 and d.gamma to 1
#
# You may get warnings that some parameters are not defined in the file, this is fine as they will be defined in this workbook anyway

# %%
d = loader.photon_hdf5(filename)
#d.leakage = 0.081
#d.dir_ex = 0.076
#d.gamma = 0.856
#d.beta = 0.87
d.leakage = 0.
d.dir_ex = 0.
d.gamma = 1.
# Out:
# WARNING fretbursts.loader
#     No offset found, assuming offset = 0.
# WARNING fretbursts.loader
#     No offset found, assuming offset = 0.
# WARNING fretbursts.loader
#
#         The current file lacks the alternation period defintion.
#         You will need to manually add this info using:
#
#           d.add(D_ON=D_ON, A_ON=A_ON)
#
#         where `d` is a Data object and D_ON/A_ON is a tuple with start/stop
#         values defining the D/A excitation excitation period. Values are in
#         raw timestamps units.
#
# WARNING fretbursts.loader
#
#         The current file lacks the alternation period defintion.
#         You will need to manually add this info using:
#
#           d.add(D_ON=D_ON, A_ON=A_ON)
#
#         where `d` is a Data object and D_ON/A_ON is a tuple with start/stop
#         values defining the D/A excitation excitation period. Values are in
#         raw timestamps units.

# %% [markdown]
# # Check alternation cycle is correct
#
# First define alternation parameters

# %%
d.add(det_donor_accept = (0, 1),
    alex_period = 10000,
    offset = 0,
    D_ON = (0, 4500),
    A_ON = (5000, 9500))

# %% [markdown]
# If this is correct, the following histogram should look correct. It is a combined plot of every photon that arrives over the supplied alternation periods.

# %%
bpl.plot_alternation_hist(d)

# %% [markdown]
# IF THE ABOVE HISTOGRAM LOOKS WRONG: then the supplied alternation parameters do not match up to the alternation of the lasers in the data. This could be because the lasers were actually on a different alternation, or because the data set doesn't start at zero so is frame shifted.
#
# IF THE ABOVE HISTOGRAM LOOKS CORRECT: execute the next command which rewrites the time stamps into groups based on their excitation period. If you want to change the alternation period after this you will have to reload the data into FRET bursts.

# %%
loader.alex_apply_period(d)
time = d.time_max
print('Total data time = %s'%time)
# Out:
# # Total photons (after ALEX selection):    14,487,665
# #  D  photons in D+A excitation periods:    8,245,518
# #  A  photons in D+A excitation periods:    6,242,147
# # D+A photons in  D  excitation period:    10,735,826
# # D+A photons in  A  excitation period:     3,751,839
#
# Total data time = 10799.90933468

# %% [markdown]
# The following will plot a time trace of the first second of your experiment.

# %%
dplot(d, timetrace, binwidth=1e-3, tmin=0, tmax=15, figsize=(10,8))
plt.xlim(10,15);
plt.ylim(-50,50);

# %% [markdown]
# # Background Estimation

# %% [markdown]
# Background estimation works by plotting log of photons by the delay between them, assuming a poisson distribution of photon arrivals and fitting a line. The plot will contain single molecule bursts however, so a threshold (in microseconds) has to be defined where the fit begins. You can set this for all channels simultaneously, for channels individually, or attempt to have FRETbursts find the correct threshold automatically.
#
# The variable "time_s" defines the size of the windows in which background is recalculated. Lower values will make the experiment more accurately sensisitive to fluctuations in background however higher values will give more photons with which to calculate a more precise average background. If the fit fails you may need to increase this value.
#
# The following are three seperate ways to find the right threshold to fit the background, if any of these get a good fit, skip ahead.

# %%
threshold = 1500
d.calc_bg(bg.exp_fit, time_s=300, tail_min_us=(threshold),)
dplot(d, hist_bg, show_fit=True)
# Out:
#  - Calculating BG rates ... [DONE]

# %% [markdown]
# This code lets you set the threshold individually for each photon stream, note that the fourth stream counts AD photons which are effectively negligible

# %%
d.ph_streams
# Out:
# [Ph_sel(Dex='DAem', Aex='DAem'),
#  Ph_sel(Dex='Dem', Aex=None),
#  Ph_sel(Dex='Aem', Aex=None),
#  Ph_sel(Dex=None, Aex='Dem'),
#  Ph_sel(Dex=None, Aex='Aem')]

# %% [markdown]
# This attempts to find the background rate for each stream automatically, but can fail for particularly noisey samples

# %% [markdown]
# This code will plot the calculated background in each window and acts as a good reporter of whether anything major has happened to the solution over the time course of the experiment

# %%
dplot(d, timetrace_bg);

# %% [markdown]
# ### Burst Searching and Selecting
#
# M = the number of photons to look at at any time
# F = the number of times higher than the background the photon rate must be to be considered a burst
# L = the number of photons that must be in a burst to be considered a burst
#
# The burst selection then selects only bursts that are size th1 or higher. add_naa=True ensures acceptor photons under acceptor excitation are encluded in the search.
#
# The below code selects for bursts which have a total of 10 photons in all three streams, and then at least 40 in DD+DA and at at least 10 in AA

# %%
d.burst_search(L=100, m=10, F=65)
ds = d.select_bursts(select_bursts.size, add_naa=True, th1=50,)
#ds = ds.select_bursts(select_bursts.size, th1=50)
#ds = ds.select_bursts(select_bursts.naa , th1=10)
# Out:
#  - Performing burst search (verbose=False) ...[DONE]
#  - Calculating burst periods ...[DONE]
#  - Counting D and A ph and calculating FRET ...
#    - Applying background correction.
#    [DONE Counting D/A]

# %% [markdown]
# Instead of that we can use a dual channel burst search, and perform the same selections on this

# %%
from fretbursts.burstlib_ext import burst_search_and_gate

# %%
ds2=burst_search_and_gate(d, F=(45), m=10, mute=True)

# %%
sizes = ds2.burst_sizes_ich(add_naa=True)
plt.hist(sizes, cumulative=-1, bins = 30, range = (0, 100), histtype="stepfilled", density=False)
plt.xlabel('Burst size')
plt.ylabel("N bursts with >")
# Out:
# Text(0,0.5,'N bursts with >')

# %%
#ds2 = ds.select_bursts(select_bursts.size, add_naa=True, th1=20,) #all channels
ds2 = ds.select_bursts(select_bursts.size, th1=50) #DD + DA
#ds2 = ds2.select_bursts(select_bursts.naa , th1=10) #AA

# %% [markdown]
# # Analysis
#
# now we can start plotting and fitting the data
#
# The following command will plot an ES heatmap and hexmap, note that it will likely throw up errors with donor only populations as there will not be sufficient data
#
# changing colourscheme = will change the colours of all charts, go to https://matplotlib.org/users/colormaps.html for a list of colour schemes, most work best if you put "_r" at the end of the name as this inverts it and typically places the lighter colour on the outside

# %%
plt.rcParams['axes.facecolor'] = '0.95'
plt.rcParams['grid.color'] = 'white'

colourscheme = 'viridis_r'
g=alex_jointplot(ds, cmap=colourscheme, marginal_color=20)
plt.rcParams['figure.figsize'] = [10,10]

# %% [markdown]
# This will fit a gaussian to the E values.
#
# If you set pdf=True then the data will be displayed as a probability density function, pdf=False will give it as bursts instead

# %%
model = mfit.factory_gaussian()
model.set_param_hint('center', value=1.1, vary=True)
ds2.E_fitter.fit_histogram(model=model, verbose=False, pdf=False)
dplot(ds2, hist_fret, pdf=False, show_model=True, show_fit_value=True, fit_from='center');
ds2.E_fitter.params
# Out:
#   amplitude    center      sigma
# 0   22.4093  0.768445  0.0681221

# %% [markdown]
# This will give burst length

# %%
dplot(ds2, hist_width, bins=(0, 20, 0.2))

# %% [markdown]
# This will fit two gaussians if you want to do that.

# %%
model = mfit.factory_two_gaussians()
model.set_param_hint('p1_center', value=0.2, vary=True)
model.set_param_hint('p2_center', value=0.65, vary=True)
ds2.E_fitter.fit_histogram(model=model, verbose=False)
dplot(ds2, hist_fret, binwidth=0.025, show_model=True, pdf=True, show_fit_value=False,);
ds2.E_fitter.params
# Out:
#   p1_amplitude p1_center   p1_sigma p2_amplitude p2_center   p2_sigma
# 0     0.467279  0.173362  0.0546478     0.529986  0.161634  0.0953413

# %% [markdown]
# This will export the data to a .csv file, type the save location between the ""'s. This csv file can be opened in excel or origin and contains information about each burst, most importantly E and S but also things like burst length and width.

# %%
csvfile = "definitiveset/2dgaussgamma/1cx.csv"
bursts = bext.burst_data(ds2)
bursts.to_csv(csvfile)
